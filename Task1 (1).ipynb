# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('Dataset.csv')

# %%
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
df.describe()
# Out:
#        Restaurant ID  Country Code    Longitude     Latitude  \
# count   9.551000e+03   9551.000000  9551.000000  9551.000000
# mean    9.051128e+06     18.365616    64.126574    25.854381
# std     8.791521e+06     56.750546    41.467058    11.007935
# min     5.300000e+01      1.000000  -157.948486   -41.330428
# 25%     3.019625e+05      1.000000    77.081343    28.478713
# 50%     6.004089e+06      1.000000    77.191964    28.570469
# 75%     1.835229e+07      1.000000    77.282006    28.642758
# max     1.850065e+07    216.000000   174.832089    55.976980
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9551.000000  9551.000000       9551.000000   9551.000000
# mean            1199.210763     1.804837          2.666370    156.909748
# std            16121.183073     0.905609          1.516378    430.169145
# min                0.000000     1.000000          0.000000      0.000000
# ...

# %%
df['Aggregate rating'].unique()
# Out:
# array([4.8, 4.5, 4.4, 4.9, 4. , 4.2, 4.3, 3.6, 4.7, 3. , 3.8, 3.7, 3.2,
#        3.1, 0. , 4.1, 3.3, 4.6, 3.9, 3.4, 3.5, 2.2, 2.9, 2.4, 2.6, 2.8,
#        2.1, 2.7, 2.5, 1.8, 2. , 2.3, 1.9])

# %%
df.select_dtypes(include='number').corr()['Aggregate rating'].drop('Aggregate rating')
# Out:
# Restaurant ID          -0.326212
# Country Code            0.282189
# Longitude              -0.116818
# Latitude                0.000516
# Average Cost for two    0.051792
# Price range             0.437944
# Votes                   0.313691
# Name: Aggregate rating, dtype: float64

# %%
df_corr=df.select_dtypes(include='number').corr().drop('Aggregate rating')

# %%
sns.heatmap(df_corr,annot=True)
# Out:
# <Axes: >

# %%
df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
df['Cuisines'].unique()
# Out:
# array(['French, Japanese, Desserts', 'Japanese',
#        'Seafood, Asian, Filipino, Indian', ..., 'Burger, Izgara',
#        'World Cuisine, Patisserie, Cafe', 'Italian, World Cuisine'],
#       dtype=object)

# %%
df[df['Cuisines'].isnull()==True]
# Out:
#      Restaurant ID                 Restaurant Name  Country Code  \
# 84        17284105                   Cookie Shoppe           216
# 87        17284211  Pearly's Famous Country Cookng           216
# 94        17284158               Jimmie's Hot Dogs           216
# 297       17374552                  Corkscrew Cafe           216
# 328       17501439                        Dovetail           216
# 346       17606621            HI Lite Bar & Lounge           216
# 368       17059060                       Hillstone           216
# 418       17142698                Leonard's Bakery           216
# 455       17616465        Tybee Island Social Club           216
#
#                City                                          Address  \
# 84           Albany               115 N Jackson St, Albany, GA 31701
# 87           Albany             814 N Slappey Blvd, Albany, GA 31701
# 94           Albany               204 S Jackson St, Albany, GA 31701
# ...

# %%
df['Cuisines'] = df['Cuisines'].fillna('Unknown')

# %%
df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                0
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
df.select_dtypes(include='object').columns
# Out:
# Index(['Restaurant Name', 'City', 'Address', 'Locality', 'Locality Verbose',
#        'Cuisines', 'Currency', 'Has Table booking', 'Has Online delivery',
#        'Is delivering now', 'Switch to order menu', 'Rating color',
#        'Rating text'],
#       dtype='object')

# %%
plt.figure(figsize=(10,2))
sns.countplot(x='Aggregate rating',data=df)
# Out:
# <Axes: xlabel='Aggregate rating', ylabel='count'>

# %%
df.groupby('Cuisines')['Aggregate rating'].mean().sort_values(ascending=False)
# Out:
# Cuisines
# Continental, Indian                     4.9
# BBQ, Breakfast, Southern                4.9
# Italian, Deli                           4.9
# American, Caribbean, Seafood            4.9
# Burger, Bar Food, Steak                 4.9
#                                        ...
# Nepalese, Tibetan                       0.0
# Seafood, Mughlai, North Indian          0.0
# North Indian, Fast Food, Mithai         0.0
# North Eastern, North Indian, Chinese    0.0
# Cafe, Tibetan                           0.0
# Name: Aggregate rating, Length: 1826, dtype: float64

# %%
df['Cuisines'].unique()
# Out:
# array(['French, Japanese, Desserts', 'Japanese',
#        'Seafood, Asian, Filipino, Indian', ..., 'Burger, Izgara',
#        'World Cuisine, Patisserie, Cafe', 'Italian, World Cuisine'],
#       dtype=object)

# %%
sns.boxplot(x='Has Table booking',y='Aggregate rating',data=df)
# Out:
# <Axes: xlabel='Has Table booking', ylabel='Aggregate rating'>

# %%
sns.boxplot(x='Has Online delivery',y='Aggregate rating',data=df)
# Out:
# <Axes: xlabel='Has Online delivery', ylabel='Aggregate rating'>

# %%
sns.boxplot(x='Is delivering now',y='Aggregate rating',data=df)
# Out:
# <Axes: xlabel='Is delivering now', ylabel='Aggregate rating'>

# %%
df.select_dtypes(include='object').columns
# Out:
# Index(['Restaurant Name', 'City', 'Address', 'Locality', 'Locality Verbose',
#        'Cuisines', 'Currency', 'Has Table booking', 'Has Online delivery',
#        'Is delivering now', 'Switch to order menu', 'Rating color',
#        'Rating text'],
#       dtype='object')

# %%
df['Switch to order menu'].unique()
# Out:
# array(['No'], dtype=object)

# %%
df=df.drop('Switch to order menu',axis=1)

# %%
df['Rating color'].unique()
# Out:
# array(['Dark Green', 'Green', 'Yellow', 'Orange', 'White', 'Red'],
#       dtype=object)

# %%
df['Rating text'].unique()
# Out:
# array(['Excellent', 'Very Good', 'Good', 'Average', 'Not rated', 'Poor'],
#       dtype=object)

# %%
sns.barplot(x='Rating color',y='Aggregate rating',data=df)
# Out:
# <Axes: xlabel='Rating color', ylabel='Aggregate rating'>

# %%
sns.barplot(x='Rating text',y='Aggregate rating',data=df)
# Out:
# <Axes: xlabel='Rating text', ylabel='Aggregate rating'>

# %%
df=df.drop(['Rating text','Rating color'],axis=1)
#dropped rating color and rating text as both these just implies aggregate color and doesnt actually add any value for the model

# %%
df=df.drop(['Restaurant ID','Restaurant Name', 'Country Code','Address',
       'Locality', 'Locality Verbose', 'Longitude', 'Latitude'],axis=1)

# %%
plt.figure(figsize=(12,5))
df.groupby('City')['Aggregate rating'].mean().sort_values(ascending=False).plot()
# Out:
# <Axes: xlabel='City'>

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
df['Average Cost for two'] = scaler.fit_transform(df[['Average Cost for two']])

# %%
df['Average Cost for two']
# Out:
# 0      -0.006154
# 1       0.000049
# 2       0.173743
# 3       0.018659
# 4       0.018659
#           ...
# 9546   -0.069428
# 9547   -0.067878
# 9548   -0.063845
# 9549   -0.066947
# 9550   -0.070979
# Name: Average Cost for two, Length: 9551, dtype: float64

# %%
df.columns
# Out:
# Index(['City', 'Cuisines', 'Average Cost for two', 'Currency',
#        'Has Table booking', 'Has Online delivery', 'Is delivering now',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
plt.figure(figsize=(25,4))
sns.barplot(x='Currency',y='Aggregate rating',data=df)
# Out:
# <Axes: xlabel='Currency', ylabel='Aggregate rating'>

# %%
df=df.drop('Currency',axis=1)
#since all currency except indian rupees have similar rating, hence it doesnt contribute much in determining the aggregate rating

# %%
df['Cuisines'].nunique()
# Out:
# 1826

# %%
df=df.drop('Cuisines',axis=1)

# %%
df.columns
# Out:
# Index(['City', 'Average Cost for two', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Price range',
#        'Aggregate rating', 'Rating color', 'Rating text', 'Votes'],
#       dtype='object')

# %%
df['City'].nunique()
# Out:
# 141

# %%
df=df.drop('City',axis=1)

# %%
df.head()
# Out:
#    Average Cost for two Has Table booking Has Online delivery  \
# 0             -0.006154               Yes                  No
# 1              0.000049               Yes                  No
# 2              0.173743               Yes                  No
# 3              0.018659                No                  No
# 4              0.018659               Yes                  No
#
#   Is delivering now  Price range  Aggregate rating Rating color Rating text  \
# 0                No            3               4.8   Dark Green   Excellent
# 1                No            3               4.5   Dark Green   Excellent
# 2                No            4               4.4        Green   Very Good
# 3                No            4               4.9   Dark Green   Excellent
# 4                No            4               4.8   Dark Green   Excellent
#
#    Votes
# 0    314
# 1    591
# 2    270
# 3    365
# 4    229

# %%
df['Votes'] = scaler.fit_transform(df[['Votes']])

# %%
df = pd.get_dummies(df, columns=['Has Table booking', 'Has Online delivery', 'Is delivering now'], drop_first=True)

# %%
df.head()
# Out:
#    Average Cost for two  Price range  Aggregate rating     Votes  \
# 0             -0.006154            3               4.8  0.365202
# 1              0.000049            3               4.5  1.009168
# 2              0.173743            4               4.4  0.262911
# 3              0.018659            4               4.9  0.483766
# 4              0.018659            4               4.8  0.167595
#
#    Has Table booking_Yes  Has Online delivery_Yes  Is delivering now_Yes
# 0                   True                    False                  False
# 1                   True                    False                  False
# 2                   True                    False                  False
# 3                  False                    False                  False
# 4                   True                    False                  False

# %%
from sklearn.model_selection import train_test_split
X=df.drop('Aggregate rating',axis=1)
y=df['Aggregate rating']
X_train,X_test,y_train,y_test= train_test_split(X,y,test_size=0.3,random_state=42)

# %%
from sklearn.linear_model import LinearRegression, LogisticRegression
model_lnr = LinearRegression()  
model_lnr.fit(X_train, y_train)
predictions_lnr = model_lnr.predict(X_test)

# %%
from sklearn.ensemble import RandomForestRegressor
model_rf = RandomForestRegressor()
model_rf.fit(X_train, y_train)
predictions_rf = model_rf.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score,root_mean_squared_error

# %%
print("Linear Regression model metrics")
print("R² Score:", r2_score(y_test, predictions_lnr))
print("MAE:", mean_absolute_error(y_test, predictions_lnr))
print("MSE:", mean_squared_error(y_test, predictions_lnr))
print("RMSE:", root_mean_squared_error(y_test, predictions_lnr))
# Out:
# Linear Regression model metrics
# R² Score: 0.255286014178273
# MAE: 1.0770205174942031
# MSE: 1.6851268152177856
# RMSE: 1.2981243450524242

# %%
print("Random Forest Regressor model metrics")
print("R² Score:", r2_score(y_test, predictions_rf))
print("MAE:", mean_absolute_error(y_test, predictions_rf))
print("MSE:", mean_squared_error(y_test, predictions_rf))
print("RMSE:", root_mean_squared_error(y_test, predictions_rf))
# Out:
# Random Forest Regressor model metrics
# R² Score: 0.9373821702178589
# MAE: 0.24464198585087402
# MSE: 0.14169061691542964
# RMSE: 0.3764181410551697

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(x=y_test, y=predictions_lnr)
plt.xlabel("Actual Ratings")
plt.ylabel("Predicted Ratings")
plt.title("Actual vs Predicted Ratings (Linear regression)")
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--') # Perfect prediction line
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(x=y_test, y=predictions_rf)
plt.xlabel("Actual Ratings")
plt.ylabel("Predicted Ratings")
plt.title("Actual vs Predicted Ratings (Random Forest)")
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--') # Perfect prediction line
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(12,6))
plt.plot(y_test.values[:100], label='Actual', marker='o')
plt.plot(predictions_lnr[:100], label='Predicted', marker='x')
plt.title("Actual vs Predicted Ratings (First 100 Samples)")
plt.xlabel("Sample Index")
plt.ylabel("Aggregate Rating")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# In this task, the objective was to predict the aggregate rating of restaurants based on various features available in the dataset.
# I began by loading the dataset and exploring it using functions like head, info, and describe to understand its structure.
#
# I then checked for missing values and found that the ‘Cuisines’ column had a few null entries, which I replaced with ‘Unknown’.
#
# Several columns like ‘Restaurant Name’, ‘Address’, ‘Locality’, ‘Locality Verbose’, ‘Switch to order menu’, ‘Rating text’, and ‘Currency’
# were dropped as they either had high cardinality, were repetitive, or did not contribute meaningfully to prediction.
#
# For categorical columns with ‘Yes’ or ‘No’ values such as ‘Has Table booking’, ‘Has Online delivery’, and ‘Is delivering now’,
# I applied one-hot encoding.
#
# Next, I explored the relationships between features and the target variable using correlation analysis for numerical columns and visualizations
# like bar plots for categorical ones.
#
# I scaled numerical features like 'Average Cost for two' and 'Votes' to bring them onto a comparable range.
# After preprocessing, I selected relevant features and split the data into training and testing sets.
#
# I trained two models: Linear Regression and Random Forest Regressor.
# The evaluation metrics revealed that Random Forest outperformed Linear Regression, with a much higher R² score and significantly lower error metrics like
# MAE, MSE, and RMSE.
#
# To better understand model performance, I visualized actual vs predicted ratings using line plots and scatter plots.
# Overall, the Random Forest model was a strong predictor of restaurant ratings
